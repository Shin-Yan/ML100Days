# %% [markdown]
# # [作業目標]
#
# 1. [簡答題] 請問 Pandas 套件最主要的貢獻是什麼？
#
# 2. 根據提供的資料集，印出他們的屬性分別為何？
# （屬性：shape、size、values、index、columns、dtypes、len）

# %% [markdown]
# # 作業

# %% [markdown]
# ### 1. [簡答題] 請問 Pandas 套件最主要的貢獻是什麼？

# %%
print("提供高效的DataFrame結構, 對於資料格式有高度銜接性, 對CSV,Excel,SQL 皆能提供彈性的讀寫工具")
# Out:
# 提供高效的DataFrame結構, 對於資料格式有高度銜接性, 對CSV,Excel,SQL 皆能提供彈性的讀寫工具

# %% [markdown]
# ### 2. 根據提供的資料集，印出他們的屬性分別為何？
# （屬性：shape、size、values、index、columns、dtypes、len）

# %%
# 記得先 Import 正確的套件

import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MachineLearningLiuMing/scikit-learn-primer-guide/master/Data.csv')
print("shape : ",df.shape,"\n")
print("size : ",df.size,"\n")
print("values : \n",df.values,"\n")
print("index : ",df.index,"\n")
print("columns : ",df.columns,"\n")
print("dtypes : \n",df.dtypes,"\n")
print("len : ",len(df),"\n")
# Out:
# shape :  (10, 4)
#
# size :  40
#
# values :
#  [['France' 44.0 72000.0 'No']
#  ['Spain' 27.0 48000.0 'Yes']
#  ['Germany' 30.0 54000.0 'No']
#  ['Spain' 38.0 61000.0 'No']
#  ['Germany' 40.0 nan 'Yes']
#  ['France' 35.0 58000.0 'Yes']
#  ['Spain' nan 52000.0 'No']
#  ['France' 48.0 79000.0 'Yes']
#  ['Germany' 50.0 83000.0 'No']
#  ['France' 37.0 67000.0 'Yes']]
#
# index :  RangeIndex(start=0, stop=10, step=1)
#
# columns :  Index(['Country', 'Age', 'Salary', 'Purchased'], dtype='object')
#
# dtypes :
#  Country       object
# Age          float64
# Salary       float64
# Purchased     object
# dtype: object
#
# len :  10
